# %%
from src.config import Config
from src.prompts import CV_ANALYSIS_PROMPT

# Validate configuration
Config.validate()
print("✅ Configuration validated successfully!")
print("✅ Sample Prompt Loaded:\n", CV_ANALYSIS_PROMPT[:120], "...")
# Out:
# ✅ Configuration validated successfully!
# ✅ Sample Prompt Loaded:
#
# You are an expert AI Recruiter and Resume Parser.
#
# Analyze the following resume text:
#
# {cv_text}
#
# Please summarize and  ...

# %%
from src.agent import JobAgent

# 1. Initialize our modular agent
agent = JobAgent()

# 2. Test CV Analysis
cv_path = r"C:\Users\MANIKANTA\OneDrive\Desktop\CV-Template.pdf"
print("--- TESTING MODULAR AGENT: CV PARSING ---")
parsed_summary = agent.parse_cv(cv_path)
print(parsed_summary)
# Out:
# --- TESTING MODULAR AGENT: CV PARSING ---
# Based on the provided resume text, here is the summarized information:
#
# 1. **Candidate Full Name**: Fred Smith, CFA
#
# 2. **Highest Level of Education**: Chartered Financial Analyst (CFA), and BSc in Mathematics (First Class Honours)
#
# 3. **Technical Skills & Tools**:
#    - Financial modeling (LBO modeling)
#    - Due diligence (financial and commercial)
#    - Investment analysis (equity and debt)
#    - Proficient in Bloomberg, Business Objects, Hyperion, C++
#
# 4. **Primary Domain / Career Field**: Finance, specifically in private equity and investment banking
#
# 5. **Key Strengths**:
#    - Extensive experience in managing investment deals and due diligence processes
#    - Strong analytical and research skills demonstrated through deal evaluations and market analysis
#    - Leadership and team management capabilities
#    - Proven ability to navigate complex financial situations and provide strategic recommendations
# ...
